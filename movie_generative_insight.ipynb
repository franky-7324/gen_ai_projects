# %% [markdown]
# # Generative Insights with BigQuery SQL and Vertex AI

# %% [markdown]
# ## Step 1: Configuration and setup

# %%
import subprocess
import sys
import pkg_resources
from google.cloud import bigquery

# List of packages to install
packages = [
    'google-auth',
    'google-auth-oauthlib',
    'google-auth-httplib2',
    'matplotlib',
    'google-api-python-client',
    'google-cloud-aiplatform',
    'langchain==0.0.340',
    'chromadb==0.4.13',
    'google-cloud-bigquery'
]

# Function to check if a package is installed
def is_package_installed(package_name):
    try:
        pkg_resources.require(package_name)
        return True
    except pkg_resources.DistributionNotFound:
        return False
    except pkg_resources.VersionConflict:
        # In case of version conflicts, treat it as not installed
        return False

# Function to install packages
def install_packages(package_list):
    installed_packages = []
    newly_installed_packages = []
    
    for package in package_list:
        package_name = package.split('==')[0]  # Handle versioned packages
        if is_package_installed(package_name):
            installed_packages.append(package)
        else:
            subprocess.check_call([sys.executable, '-m', 'pip', 'install', package])
            newly_installed_packages.append(package)
    
    return installed_packages, newly_installed_packages

# Install the packages
installed_packages, newly_installed_packages = install_packages(packages)

# Output based on the installation result
if newly_installed_packages:
    print("The following packages were installed:")
    for package in newly_installed_packages:
        print(f" - {package}")
else:
    print("All packages are already installed.")

###############################################################################


import os
# Change to D drive
os.chdir('D:/gcp-proj-ai-ml')


from google.oauth2 import service_account

# Path to your service account key file
service_account_file = 'D:/gcp-proj-ai-ml/sa-jupyter-gcloud.json'

# Authenticate using the service account key file
credentials = service_account.Credentials.from_service_account_file(service_account_file)

from googleapiclient.discovery import build
from google.oauth2 import service_account
from prettytable import PrettyTable

# Path to your service account key file
SERVICE_ACCOUNT_FILE = 'D:/gcp-proj-ai-ml/sa-jupyter-gcloud.json'

# Define the scopes required
SCOPES = ['https://www.googleapis.com/auth/cloud-platform']

# Define the project ID
PROJECT_ID = 'project-ai-ml-434700'
# Out:
# C:\Users\anuj dubey\AppData\Local\Temp\ipykernel_24092\1650153365.py:3: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   import pkg_resources
# All packages are already installed.

# %% [markdown]
# ## Preparing Data

# %%
# use the bq mk command to create a dataset called "movie_insights"
# !bq mk --location=us-central1 movie_insights

# Clone the source file to you Cloud Shell Machine
# !git clone https://github.com/AbiramiSukumaran/movie_score_genai_insights

# change the current directory to the git downloaded directory
# !cd movie_score_genai_insights
# Out:
# Dataset 'project-ai-ml-434700:movie_insights' successfully created.
# fatal: destination path 'movie_score_genai_insights' already exists and is not an empty directory.

# %% [markdown]
# ## Navigate to the new project directory that is created and load the csv to the BQ dataset created

# %%
# Navigate to the new project directory that is created

import os
# Change to D drive
os.chdir('D:/gcp-proj-ai-ml/movie_score_genai_insights')

# Use the bq load command to load your CSV file into a BigQuery table

# !bq load --source_format=CSV --skip_leading_rows=1 \
movie_insights.movie_score \
./movies_data.csv \
Id:numeric,name:string,rating:string,genre:string,year:numeric,released:string,score:string,director:string,writer:string,star:string,country:string,budget:numeric,company:string,runtime:numeric,data_cat:string


# You can query a sample to check if the table movie_score and the data are created in the dataset

# !bq query --use_legacy_sql=false \
SELECT name, rating, genre, runtime FROM movie_insights.movie_score limit 3;
# Out:
# Upload complete.
#
# Waiting on bqjob_r1a02899163520087_00000191f1aeb2a1_1 ... (0s) Current status: RUNNING
#
# Waiting on bqjob_r1a02899163520087_00000191f1aeb2a1_1 ... (0s) Current status: DONE
# +------------------+-----------+--------+---------+
# |       name       |  rating   | genre  | runtime |
# +------------------+-----------+--------+---------+
# | Love by Drowning | R         | Drama  |     121 |
# | It's Just Us     | Not Rated | Drama  |     120 |
# | The Robinsons    | Not Rated | Action |      90 |
# +------------------+-----------+--------+---------+

# %%
# # You can query a sample to check if the table movie_score and the data are created in the dataset

# !bq query --use_legacy_sql=false \
# SELECT name, rating, genre, runtime FROM movie_insights.movie_score limit 5;
# Out:
# +------------------+-----------+--------+---------+
# |       name       |  rating   | genre  | runtime |
# +------------------+-----------+--------+---------+
# | Love by Drowning | R         | Drama  |     121 |
# | It's Just Us     | Not Rated | Drama  |     120 |
# | The Robinsons    | Not Rated | Action |      90 |
# | Glitter          | PG-13     | Drama  |     104 |
# | Leonard Part 6   | PG        | Action |      85 |
# +------------------+-----------+--------+---------+

# %% [markdown]
# ## Create a classification model to predict the success score of the movie based on GENRE and RUNTIME attributes.

# %%
client = bigquery.Client()

QUERY_TRAIN = ("""
        CREATE OR REPLACE MODEL
  `movie_insights.model_rating_by_runtime_genre_01`
OPTIONS
  ( model_type='LOGISTIC_REG',
    auto_class_weights=TRUE,
    data_split_method='NO_SPLIT',
    model_registry='vertex_ai',   
    vertex_ai_model_version_aliases=['logistic_reg', 'experimental'],
    input_label_cols=['score']
  ) AS
SELECT name, genre,runtime, score
FROM
  movie_insights.movie_score
WHERE
  data_cat = 'TRAIN';
          """)

query_job_train = client.query(QUERY_TRAIN)
# df_train = query_job_train.to_dataframe()
# df_train.head()

# %% [markdown]
# ## Predicting movie score using the model

# %%
# Predicting movie score using the model

client = bigquery.Client()

QUERY_PREDICT = ("""
        SELECT
          *
        FROM
          ML.PREDICT (MODEL movie_insights.model_rating_by_runtime_genre,
            (
            SELECT
              *
            FROM
              movie_insights.movie_score
            WHERE
              data_cat= 'TEST'
             )
          );
          """)

query_job_predict = client.query(QUERY_PREDICT)
df_prediction = query_job_predict.to_dataframe()
df_prediction.head()
# Out:
# C:\Users\anuj dubey\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\cloud\bigquery\table.py:1727: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
#   predicted_score                              predicted_score_probs  \
# 0               7  [{'label': '7', 'prob': 0.337056592816488}, {'...
# 1               7  [{'label': '7', 'prob': 0.3382462144242809}, {...
# 2               7  [{'label': '7', 'prob': 0.3602429747290255}, {...
# 3               7  [{'label': '7', 'prob': 0.39737381968856844}, ...
# 4               6  [{'label': '6', 'prob': 0.37572885944327344}, ...
#
#                Id                      name     rating      genre  \
# 0  7641.000000000  By Light of Desert Night  Not Rated      Drama
# 1  7656.000000000                     Tulsa      PG-13     Comedy
# 2  7655.000000000     Legend of Deification      TV-PG  Animation
# 3  7642.000000000          A Brother's Love  Not Rated      Drama
# 4  7649.000000000        Sonic the Hedgehog         PG     Action
#
#              year   released score            director              writer  \
# 0  2019.000000000   3/3/2020     5  David Stuart Snell  David Stuart Snell
# 1  2020.000000000   6/3/2020     5         Scott Pryor         Scott Pryor
# 2  2020.000000000  10/1/2020     7          Teng Cheng          Jiang Ziya
# 3  2019.000000000   6/7/2019     7        Monia Chokri        Monia Chokri
# 4  2020.000000000  2/14/2020     7         Jeff Fowler           Pat Casey
#
#                    star        country              budget  \
# 0      Alexandra Bokova  United States  57531050.000000000
# 1           Scott Pryor  United States  57531050.000000000
# 2        Guangtao Jiang          China  57531050.000000000
# 3  Anne-Élisabeth Bossé         Canada  57531050.000000000
# 4          Ben Schwartz  United States  85000000.000000000
#
#                     company        runtime data_cat
# 0              Canyon Media   94.000000000     TEST
# 1       Pryor Entertainment  120.000000000     TEST
# 2  Beijing Enlight Pictures  110.000000000     TEST
# 3                 Metafilms  117.000000000     TEST
# 4        Paramount Pictures   99.000000000     TEST

# %% [markdown]
# ## Create an External Connection

# %%
# Create an External Connection

# !bq mk --connection --location=us-central1 --project_id=project-ai-ml-434700 \
    --connection_type=CLOUD_RESOURCE bq_llm_connection
# Out:
# Connection 235498471165.us-central1.bq_llm_connection successfully created

# %% [markdown]
# ## Create a remote ML model
#
# <span style="color:red">Important</span> : Before running the step, go to the detail page of the "external connection" created and note down the SA. Then give vertex AI User" role to that Service account(SA)

# %%
# Create a remote ML model

QUERY_REMOTE_MODEL = ("""
        CREATE OR REPLACE MODEL
  movie_insights.llm_model REMOTE
WITH CONNECTION `us-central1.bq_llm_connection` OPTIONS (remote_service_type = 'CLOUD_AI_LARGE_LANGUAGE_MODEL_V1');
          """)

query_create_remote_model = client.query(QUERY_REMOTE_MODEL)

# %% [markdown]
# ## Generate text using the ML model

# %%
QUERY_CREATE_TEXT = ("""
        SELECT
  ml_generate_text_result['predictions'][0]['content'] AS generated_text,
  ml_generate_text_result['predictions'][0]['safetyAttributes']
    AS safety_attributes,
  * EXCEPT (ml_generate_text_result)
FROM
  ML.GENERATE_TEXT(
    MODEL `movie_insights.llm_model`,
    (
 SELECT
      CONCAT('FROM THE FOLLOWING TEXT ABOUT MOVIES, WHAT DO YOU THINK ARE THE FACTORS INFLUENCING A MOVIE SCORE TO BE GREATER THAN 5?: ', movie_data) AS prompt
    FROM (
      SELECT
        REPLACE(STRING_AGG( CONCAT('A movie named ',name, ' from the country ', country, ' with a censor rating of ',rating, ' and a budget of ', budget, ' produced by ', company, ' with a runtime of about ', runtime, ' and in the genre ', genre, ' starring ', star, ' has had a success score of ', score, '') ), ',','. ') AS movie_data
      FROM (
        SELECT
          *
        FROM
          `movie_insights.movie_score`
        WHERE
          CAST(SCORE AS INT64) > 5
        LIMIT
          50) ) AS MOVIES
    ),
    STRUCT(
      0.2 AS temperature,
      100 AS max_output_tokens));
          """)

# Function to wrap text to fit within column width
def wrap_text(text, width):
    # Word-wrap text manually by splitting into lines
    wrapped = "\n".join([text[i:i+width] for i in range(0, len(text), width)])
    return wrapped

query_create_text = client.query(QUERY_CREATE_TEXT)
df_gen_text = query_create_text.to_dataframe()

column_width = 30  # Around 2 inches (based on a character count of around 10-12 characters per inch)

# Initialize PrettyTable
table = PrettyTable()

# Add column names from the DataFrame
table.field_names = df_gen_text.columns

# Add rows to the PrettyTable with word wrapping applied to each cell
for row in df_gen_text.itertuples(index=False, name=None):
    wrapped_row = [wrap_text(str(cell), column_width) for cell in row]
    table.add_row(wrapped_row)

# Optional: Set alignment for all columns to be left-aligned
table.align = "l"

# Display the table
print(table)
# Out:
# +--------------------------------+--------------------------------+-------------------------+--------------------------------+
# | generated_text                 | safety_attributes              | ml_generate_text_status | prompt                         |
# +--------------------------------+--------------------------------+-------------------------+--------------------------------+
# |  Based on the provided informa | {'blocked': False, 'categories |                         | FROM THE FOLLOWING TEXT ABOUT  |
# | tion, it is difficult to deter | ': array(['Derogatory', 'Finan |                         | MOVIES, WHAT DO YOU THINK ARE  |
# | mine the exact factors influen | ce', 'Insult', 'Profanity', 'S |                         | THE FACTORS INFLUENCING A MOVI |
# | cing a movie score to be great | exual', 'Toxic'],              |                         | E SCORE TO BE GREATER THAN 5?: |
# | er than 5. However, some poten |       dtype=                   |                         |  A movie named American Gigolo |
# | tial factors that could contri | object), 'safetyRatings': arra |                         |  from the country United State |
# | bute to a higher success score | y([{'category': 'Dangerous Con |                         | s with a censor rating of R an |
# |  include:                      | tent', 'probabilityScore': 0.1 |                         | d a budget of 4800000 produced |
# |                                | , 'severity': 'NEGLIGIBLE', 's |                         |  by Paramount Pictures with a  |
# | - **Genre:** Crime             | everityScore': 0.1},           |                         | runtime of about 117 and in th |
# | movies generally tend to have  |        {'                      |                         | e genre Crime starring Richard |
# | lower success scores compared  | category': 'Harassment', 'prob |                         |  Gere has had a success score  |
# | to other genres.               | abilityScore': 0.2, 'severity' |                         | of 6. A movie named Eyewitness |
# |                                | : 'NEGLIGIBLE', 'severityScore |                         |  from the country United State |
# | - **Censor r                   | ': 0.1},                       |                         | s with a censor rating of R an |
# | ating:** Movies with a higher  |        {'category': '          |                         | d a budget of 8500000 produced |
# | censor rating (R) tend to have | Hate Speech', 'probabilityScor |                         |  by Twentieth Century Fox with |
# |  lower success scores compared | e': 0.1, 'severity': 'NEGLIGIB |                         |  a runtime of about 103 and in |
# |  to those with lower ratings ( | LE', 'severityScore': 0.1},    |                         |  the genre Crime starring Will |
# | PG).                           |                                |                         | iam Hurt has had a success sco |
# |                                |      {'category': 'Sexually Ex |                         | re of 6. A movie named True Co |
# | - **Budget:** Movies wit       | plicit', 'probabilityScore': 0 |                         | nfessions from the country Uni |
# | h higher budgets tend          | .1, 'severity': 'NEGLIGIBLE',  |                         | ted States with a censor ratin |
# |                                | 'severityScore': 0.1}],        |                         | g of R and a budget of 1000000 |
# |                                |                                |                         | 0 produced by Chartoff-Winkler |
# |                                | dtype=object), 'scores': array |                         |  Productions with a runtime of |
# |                                | ([0.1, 0.6, 0.2, 0.1, 0.1, 0.1 |                         |  about 108 and in the genre Cr |
# |                                | ])}                            |                         | ime starring Robert De Niro ha |
# |                                |                                |                         | s had a success score of 6. A  |
# |                                |                                |                         | movie named The Amateur from t |
# |                                |                                |                         | he country Canada with a censo |
# |                                |                                |                         | r rating of R and a budget of  |
# |                                |                                |                         | 35524924.14 produced by Balkan |
# |                                |                                |                         |  Productions with a runtime of |
# |                                |                                |                         |  about 112 and in the genre Cr |
# |                                |                                |                         | ime starring John Savage has h |
# |                                |                                |                         | ad a success score of 6. A mov |
# |                                |                                |                         | ie named I.  the Jury from the |
# |                                |                                |                         |  country United States with a  |
# |                                |                                |                         | censor rating of R and a budge |
# |                                |                                |                         | t of 35524924.14 produced by A |
# |                                |                                |                         | merican Cinema Productions wit |
# |                                |                                |                         | h a runtime of about 111 and i |
# |                                |                                |                         | n the genre Crime starring Arm |
# |                                |                                |                         | and Assante has had a success  |
# |                                |                                |                         | score of 6. A movie named Stil |
# |                                |                                |                         | l of the Night from the countr |
# |                                |                                |                         | y United States with a censor  |
# |                                |                                |                         | rating of PG and a budget of 1 |
# |                                |                                |                         | 0000000 produced by United Art |
# |                                |                                |                         | ists with a runtime of about 9 |
# |                                |                                |                         | 3 and in the genre Crime starr |
# |                                |                                |                         | ing Roy Scheider has had a suc |
# |                                |                                |                         | cess score of 6. A movie named |
# |                                |                                |                         |  The Border from the country U |
# |                                |                                |                         | nited States with a censor rat |
# |                                |                                |                         | ing of R and a budget of 22000 |
# |                                |                                |                         | 000 produced by Efer Productio |
# |                                |                                |                         | ns with a runtime of about 108 |
# |                                |                                |                         |  and in the genre Crime starri |
# |                                |                                |                         | ng Jack Nicholson has had a su |
# |                                |                                |                         | ccess score of 6. A movie name |
# |                                |                                |                         | d Love Child from the country  |
# |                                |                                |                         | United States with a censor ra |
# |                                |                                |                         | ting of R and a budget of 3552 |
# |                                |                                |                         | 4924.14 produced by The Ladd C |
# |                                |                                |                         | ompany with a runtime of about |
# |                                |                                |                         |  96 and in the genre Crime sta |
# |                                |                                |                         | rring Amy Madigan has had a su |
# |                                |                                |                         | ccess score of 6. A movie name |
# |                                |                                |                         | d 10 to Midnight from the coun |
# |                                |                                |                         | try United States with a censo |
# |                                |                                |                         | r rating of R and a budget of  |
# |                                |                                |                         | 4520000 produced by Cannon Fil |
# |                                |                                |                         | ms with a runtime of about 101 |
# |                                |                                |                         |  and in the genre Crime starri |
# |                                |                                |                         | ng Charles Bronson has had a s |
# |                                |                                |                         | uccess score of 6. A movie nam |
# |                                |                                |                         | ed The Star Chamber from the c |
# |                                |                                |                         | ountry United States with a ce |
# |                                |                                |                         | nsor rating of R and a budget  |
# |                                |                                |                         | of 35524924.14 produced by Twe |
# |                                |                                |                         | ntieth Century Fox with a runt |
# |                                |                                |                         | ime of about 109 and in the ge |
# |                                |                                |                         | nre Crime starring Michael Dou |
# |                                |                                |                         | glas has had a success score o |
# |                                |                                |                         | f 6. A movie named Tightrope f |
# |                                |                                |                         | rom the country United States  |
# |                                |                                |                         | with a censor rating of R and  |
# |                                |                                |                         | a budget of 35524924.14 produc |
# |                                |                                |                         | ed by The Malpaso Company with |
# |                                |                                |                         |  a runtime of about 114 and in |
# |                                |                                |                         |  the genre Crime starring Clin |
# |                                |                                |                         | t Eastwood has had a success s |
# |                                |                                |                         | core of 6. A movie named Thief |
# |                                |                                |                         |  of Hearts from the country Un |
# |                                |                                |                         | ited States with a censor rati |
# |                                |                                |                         | ng of Not Rated and a budget o |
# |                                |                                |                         | f 9000000 produced by Don Simp |
# |                                |                                |                         | son/Jerry Bruckheimer Films wi |
# |                                |                                |                         | th a runtime of about 100 and  |
# |                                |                                |                         | in the genre Crime starring St |
# |                                |                                |                         | even Bauer has had a success s |
# |                                |                                |                         | core of 6. A movie named The N |
# |                                |                                |                         | ew Kids from the country Unite |
# |                                |                                |                         | d States with a censor rating  |
# |                                |                                |                         | of R and a budget of 35524924. |
# |                                |                                |                         | 14 produced by Columbia Pictur |
# |                                |                                |                         | es with a runtime of about 110 |
# |                                |                                |                         |  and in the genre Crime starri |
# |                                |                                |                         | ng Shannon Presby has had a su |
# |                                |                                |                         | ccess score of 6. A movie name |
# |                                |                                |                         | d That Was Then... This Is Now |
# |                                |                                |                         |  from the country United State |
# |                                |                                |                         | s with a censor rating of R an |
# |                                |                                |                         | d a budget of 35524924.14 prod |
# |                                |                                |                         | uced by Media Ventures with a  |
# |                                |                                |                         | runtime of about 102 and in th |
# |                                |                                |                         | e genre Crime starring Emilio  |
# |                                |                                |                         | Estevez has had a success scor |
# |                                |                                |                         | e of 6. A movie named The Mean |
# |                                |                                |                         |  Season from the country Unite |
# |                                |                                |                         | d States with a censor rating  |
# |                                |                                |                         | of R and a budget of 7000000 p |
# |                                |                                |                         | roduced by David Foster Produc |
# |                                |                                |                         | tions with a runtime of about  |
# |                                |                                |                         | 103 and in the genre Crime sta |
# |                                |                                |                         | rring Kurt Russell has had a s |
# |                                |                                |                         | uccess score of 6. A movie nam |
# |                                |                                |                         | ed The Doctor and the Devils f |
# |                                |                                |                         | rom the country United Kingdom |
# |                                |                                |                         |  with a censor rating of R and |
# |                                |                                |                         |  a budget of 35524924.14 produ |
# |                                |                                |                         | ced by Brooksfilms with a runt |
# |                                |                                |                         | ime of about 93 and in the gen |
# |                                |                                |                         | re Crime starring Timothy Dalt |
# |                                |                                |                         | on has had a success score of  |
# |                                |                                |                         | 6. A movie named No Mercy from |
# |                                |                                |                         |  the country United States wit |
# |                                |                                |                         | h a censor rating of R and a b |
# |                                |                                |                         | udget of 14000000 produced by  |
# |                                |                                |                         | TriStar Pictures with a runtim |
# |                                |                                |                         | e of about 106 and in the genr |
# |                                |                                |                         | e Crime starring Richard Gere  |
# |                                |                                |                         | has had a success score of 6.  |
# |                                |                                |                         | A movie named Quicksilver from |
# |                                |                                |                         |  the country United States wit |
# |                                |                                |                         | h a censor rating of PG and a  |
# |                                |                                |                         | budget of 35524924.14 produced |
# |                                |                                |                         |  by Columbia Pictures with a r |
# |                                |                                |                         | untime of about 105 and in the |
# |                                |                                |                         |  genre Crime starring Kevin Ba |
# |                                |                                |                         | con has had a success score of |
# |                                |                                |                         |  6. A movie named 52 Pick-Up f |
# |                                |                                |                         | rom the country United States  |
# |                                |                                |                         | with a censor rating of R and  |
# |                                |                                |                         | a budget of 35524924.14 produc |
# |                                |                                |                         | ed by Cannon Group with a runt |
# |                                |                                |                         | ime of about 110 and in the ge |
# |                                |                                |                         | nre Crime starring Roy Scheide |
# |                                |                                |                         | r has had a success score of 6 |
# |                                |                                |                         | . A movie named The Morning Af |
# |                                |                                |                         | ter from the country United St |
# |                                |                                |                         | ates with a censor rating of R |
# |                                |                                |                         |  and a budget of 15000000 prod |
# |                                |                                |                         | uced by American Filmworks wit |
# |                                |                                |                         | h a runtime of about 103 and i |
# |                                |                                |                         | n the genre Crime starring Jan |
# |                                |                                |                         | e Fonda has had a success scor |
# |                                |                                |                         | e of 6. A movie named Wisdom f |
# |                                |                                |                         | rom the country United States  |
# |                                |                                |                         | with a censor rating of R and  |
# |                                |                                |                         | a budget of 35524924.14 produc |
# |                                |                                |                         | ed by Gladden Entertainment wi |
# |                                |                                |                         | th a runtime of about 109 and  |
# |                                |                                |                         | in the genre Crime starring Em |
# |                                |                                |                         | ilio Estevez has had a success |
# |                                |                                |                         |  score of 6. A movie named Bla |
# |                                |                                |                         | ck Widow from the country Unit |
# |                                |                                |                         | ed States with a censor rating |
# |                                |                                |                         |  of R and a budget of 10500000 |
# |                                |                                |                         |  produced by Amercent Films wi |
# |                                |                                |                         | th a runtime of about 102 and  |
# |                                |                                |                         | in the genre Crime starring De |
# |                                |                                |                         | bra Winger has had a success s |
# |                                |                                |                         | core of 6. A movie named Less  |
# |                                |                                |                         | Than Zero from the country Uni |
# |                                |                                |                         | ted States with a censor ratin |
# |                                |                                |                         | g of R and a budget of 3552492 |
# |                                |                                |                         | 4.14 produced by Twentieth Cen |
# |                                |                                |                         | tury Fox with a runtime of abo |
# |                                |                                |                         | ut 98 and in the genre Crime s |
# |                                |                                |                         | tarring Andrew McCarthy has ha |
# |                                |                                |                         | d a success score of 6. A movi |
# |                                |                                |                         | e named The Bedroom Window fro |
# |                                |                                |                         | m the country United States wi |
# |                                |                                |                         | th a censor rating of R and a  |
# |                                |                                |                         | budget of 8300000 produced by  |
# |                                |                                |                         | De Laurentiis Entertainment Gr |
# |                                |                                |                         | oup (DEG) with a runtime of ab |
# |                                |                                |                         | out 112 and in the genre Crime |
# |                                |                                |                         |  starring Steve Guttenberg has |
# |                                |                                |                         |  had a success score of 6. A m |
# |                                |                                |                         | ovie named No Man's Land from  |
# |                                |                                |                         | the country United States with |
# |                                |                                |                         |  a censor rating of R and a bu |
# |                                |                                |                         | dget of 8000000 produced by Or |
# |                                |                                |                         | ion Pictures with a runtime of |
# |                                |                                |                         |  about 106 and in the genre Cr |
# |                                |                                |                         | ime starring Charlie Sheen has |
# |                                |                                |                         |  had a success score of 6. A m |
# |                                |                                |                         | ovie named The Believers from  |
# |                                |                                |                         | the country United States with |
# |                                |                                |                         |  a censor rating of R and a bu |
# |                                |                                |                         | dget of 13000000 produced by O |
# |                                |                                |                         | rion Pictures with a runtime o |
# |                                |                                |                         | f about 114 and in the genre C |
# |                                |                                |                         | rime starring Martin Sheen has |
# |                                |                                |                         |  had a success score of 6. A m |
# |                                |                                |                         | ovie named Someone to Watch Ov |
# |                                |                                |                         | er Me from the country United  |
# |                                |                                |                         | States with a censor rating of |
# |                                |                                |                         |  R and a budget of 12800000 pr |
# |                                |                                |                         | oduced by Columbia Pictures wi |
# |                                |                                |                         | th a runtime of about 106 and  |
# |                                |                                |                         | in the genre Crime starring To |
# |                                |                                |                         | m Berenger has had a success s |
# |                                |                                |                         | core of 6. A movie named Priso |
# |                                |                                |                         | n from the country United Stat |
# |                                |                                |                         | es with a censor rating of R a |
# |                                |                                |                         | nd a budget of 4000000 produce |
# |                                |                                |                         | d by Empire Pictures with a ru |
# |                                |                                |                         | ntime of about 102 and in the  |
# |                                |                                |                         | genre Crime starring Lane Smit |
# |                                |                                |                         | h has had a success score of 6 |
# |                                |                                |                         | . A movie named Street Smart f |
# |                                |                                |                         | rom the country United States  |
# |                                |                                |                         | with a censor rating of R and  |
# |                                |                                |                         | a budget of 5000000 produced b |
# |                                |                                |                         | y Golan-Globus Productions wit |
# |                                |                                |                         | h a runtime of about 97 and in |
# |                                |                                |                         |  the genre Crime starring Chri |
# |                                |                                |                         | stopher Reeve has had a succes |
# |                                |                                |                         | s score of 6. A movie named Wh |
# |                                |                                |                         | ite Mischief from the country  |
# |                                |                                |                         | United Kingdom with a censor r |
# |                                |                                |                         | ating of R and a budget of 530 |
# |                                |                                |                         | 0000 produced by Columbia Pict |
# |                                |                                |                         | ures with a runtime of about 1 |
# |                                |                                |                         | 07 and in the genre Crime star |
# |                                |                                |                         | ring Sarah Miles has had a suc |
# |                                |                                |                         | cess score of 6. A movie named |
# |                                |                                |                         |  China Girl from the country U |
# |                                |                                |                         | nited States with a censor rat |
# |                                |                                |                         | ing of R and a budget of 35524 |
# |                                |                                |                         | 924.14 produced by Great Ameri |
# |                                |                                |                         | can Films Limited Partnership  |
# |                                |                                |                         | with a runtime of about 90 and |
# |                                |                                |                         |  in the genre Crime starring J |
# |                                |                                |                         | ames Russo has had a success s |
# |                                |                                |                         | core of 6. A movie named Five  |
# |                                |                                |                         | Corners from the country Unite |
# |                                |                                |                         | d Kingdom with a censor rating |
# |                                |                                |                         |  of R and a budget of 5500000  |
# |                                |                                |                         | produced by Cineplex Odeon Fil |
# |                                |                                |                         | ms with a runtime of about 90  |
# |                                |                                |                         | and in the genre Crime starrin |
# |                                |                                |                         | g Jodie Foster has had a succe |
# |                                |                                |                         | ss score of 6. A movie named T |
# |                                |                                |                         | equila Sunrise from the countr |
# |                                |                                |                         | y United States with a censor  |
# |                                |                                |                         | rating of R and a budget of 23 |
# |                                |                                |                         | 000000 produced by Cinema City |
# |                                |                                |                         |  Films with a runtime of about |
# |                                |                                |                         |  115 and in the genre Crime st |
# |                                |                                |                         | arring Mel Gibson has had a su |
# |                                |                                |                         | ccess score of 6. A movie name |
# |                                |                                |                         | d Betrayed from the country Ja |
# |                                |                                |                         | pan with a censor rating of R  |
# |                                |                                |                         | and a budget of 19000000 produ |
# |                                |                                |                         | ced by United Artists with a r |
# |                                |                                |                         | untime of about 127 and in the |
# |                                |                                |                         |  genre Crime starring Debra Wi |
# |                                |                                |                         | nger has had a success score o |
# |                                |                                |                         | f 6. A movie named Appointment |
# |                                |                                |                         |  with Death from the country U |
# |                                |                                |                         | nited States with a censor rat |
# |                                |                                |                         | ing of PG and a budget of 6000 |
# |                                |                                |                         | 000 produced by Golan-Globus P |
# |                                |                                |                         | roductions with a runtime of a |
# |                                |                                |                         | bout 102 and in the genre Crim |
# |                                |                                |                         | e starring Peter Ustinov has h |
# |                                |                                |                         | ad a success score of 6. A mov |
# |                                |                                |                         | ie named Jack's Back from the  |
# |                                |                                |                         | country United States with a c |
# |                                |                                |                         | ensor rating of R and a budget |
# |                                |                                |                         |  of 1000000 produced by Cinema |
# |                                |                                |                         |  Group with a runtime of about |
# |                                |                                |                         |  97 and in the genre Crime sta |
# |                                |                                |                         | rring James Spader has had a s |
# |                                |                                |                         | uccess score of 6. A movie nam |
# |                                |                                |                         | ed Sunset from the country Uni |
# |                                |                                |                         | ted States with a censor ratin |
# |                                |                                |                         | g of R and a budget of 1600000 |
# |                                |                                |                         | 0 produced by Cecchi Gori Grou |
# |                                |                                |                         | p Tiger Cinematografica with a |
# |                                |                                |                         |  runtime of about 102 and in t |
# |                                |                                |                         | he genre Crime starring Bruce  |
# |                                |                                |                         | Willis has had a success score |
# |                                |                                |                         |  of 6. A movie named Cop from  |
# |                                |                                |                         | the country United States with |
# |                                |                                |                         |  a censor rating of R and a bu |
# |                                |                                |                         | dget of 3000000 produced by At |
# |                                |                                |                         | lantic Entertainment Group wit |
# |                                |                                |                         | h a runtime of about 110 and i |
# |                                |                                |                         | n the genre Crime starring Jam |
# |                                |                                |                         | es Woods has had a success sco |
# |                                |                                |                         | re of 6. A movie named Stormy  |
# |                                |                                |                         | Monday from the country United |
# |                                |                                |                         |  Kingdom with a censor rating  |
# |                                |                                |                         | of R and a budget of 4000000 p |
# |                                |                                |                         | roduced by Atlantic Entertainm |
# |                                |                                |                         | ent Group with a runtime of ab |
# |                                |                                |                         | out 93 and in the genre Crime  |
# |                                |                                |                         | starring Melanie Griffith has  |
# |                                |                                |                         | had a success score of 6. A mo |
# |                                |                                |                         | vie named Kansas from the coun |
# |                                |                                |                         | try United States with a censo |
# |                                |                                |                         | r rating of R and a budget of  |
# |                                |                                |                         | 35524924.14 produced by Trans  |
# |                                |                                |                         | World Entertainment (TWE) with |
# |                                |                                |                         |  a runtime of about 108 and in |
# |                                |                                |                         |  the genre Crime starring Matt |
# |                                |                                |                         |  Dillon has had a success scor |
# |                                |                                |                         | e of 6. A movie named Criminal |
# |                                |                                |                         |  Law from the country United S |
# |                                |                                |                         | tates with a censor rating of  |
# |                                |                                |                         | R and a budget of 35524924.14  |
# |                                |                                |                         | produced by Hemdale with a run |
# |                                |                                |                         | time of about 117 and in the g |
# |                                |                                |                         | enre Crime starring Gary Oldma |
# |                                |                                |                         | n has had a success score of 6 |
# |                                |                                |                         | . A movie named Johnny Handsom |
# |                                |                                |                         | e from the country United Stat |
# |                                |                                |                         | es with a censor rating of R a |
# |                                |                                |                         | nd a budget of 20000000 produc |
# |                                |                                |                         | ed by Carolco Pictures with a  |
# |                                |                                |                         | runtime of about 94 and in the |
# |                                |                                |                         |  genre Crime starring Mickey R |
# |                                |                                |                         | ourke has had a success score  |
# |                                |                                |                         | of 6. A movie named Family Bus |
# |                                |                                |                         | iness from the country United  |
# |                                |                                |                         | States with a censor rating of |
# |                                |                                |                         |  R and a budget of 35524924.14 |
# |                                |                                |                         |  produced by TriStar Pictures  |
# |                                |                                |                         | with a runtime of about 110 an |
# |                                |                                |                         | d in the genre Crime starring  |
# |                                |                                |                         | Sean Connery has had a success |
# |                                |                                |                         |  score of 6. A movie named Rel |
# |                                |                                |                         | entless from the country Unite |
# |                                |                                |                         | d States with a censor rating  |
# |                                |                                |                         | of R and a budget of 4000000 p |
# |                                |                                |                         | roduced by Cinetel Films with  |
# |                                |                                |                         | a runtime of about 92 and in t |
# |                                |                                |                         | he genre Crime starring Judd N |
# |                                |                                |                         | elson has had a success score  |
# |                                |                                |                         | of 6. A movie named The Hot Sp |
# |                                |                                |                         | ot from the country United Sta |
# |                                |                                |                         | tes with a censor rating of R  |
# |                                |                                |                         | and a budget of 13000000 produ |
# |                                |                                |                         | ced by Orion Pictures with a r |
# |                                |                                |                         | untime of about 130 and in the |
# |                                |                                |                         |  genre Crime starring Don John |
# |                                |                                |                         | son has had a success score of |
# |                                |                                |                         |  6. A movie named The Two Jake |
# |                                |                                |                         | s from the country United Stat |
# |                                |                                |                         | es with a censor rating of R a |
# |                                |                                |                         | nd a budget of 19000000 produc |
# |                                |                                |                         | ed by 88 Productions with a ru |
# |                                |                                |                         | ntime of about 137 and in the  |
# |                                |                                |                         | genre Crime starring Jack Nich |
# |                                |                                |                         | olson has had a success score  |
# |                                |                                |                         | of 6. A movie named The First  |
# |                                |                                |                         | Power from the country United  |
# |                                |                                |                         | States with a censor rating of |
# |                                |                                |                         |  R and a budget of 10000000 pr |
# |                                |                                |                         | oduced by Interscope Communica |
# |                                |                                |                         | tions with a runtime of about  |
# |                                |                                |                         | 98 and in the genre Crime star |
# |                                |                                |                         | ring Lou Diamond Phillips has  |
# |                                |                                |                         | had a success score of 6. A mo |
# |                                |                                |                         | vie named Impulse from the cou |
# |                                |                                |                         | ntry United States with a cens |
# |                                |                                |                         | or rating of R and a budget of |
# |                                |                                |                         |  9000000 produced by Warner Br |
# |                                |                                |                         | os. with a runtime of about 10 |
# |                                |                                |                         | 9 and in the genre Crime starr |
# |                                |                                |                         | ing Theresa Russell has had a  |
# |                                |                                |                         | success score of 6. A movie na |
# |                                |                                |                         | med Crossing the Line from the |
# |                                |                                |                         |  country United Kingdom with a |
# |                                |                                |                         |  censor rating of R and a budg |
# |                                |                                |                         | et of 35524924.14 produced by  |
# |                                |                                |                         | Palace Pictures with a runtime |
# |                                |                                |                         |  of about 93 and in the genre  |
# |                                |                                |                         | Crime starring Kenny Ireland h |
# |                                |                                |                         | as had a success score of 6. A |
# |                                |                                |                         |  movie named Mobsters from the |
# |                                |                                |                         |  country United States with a  |
# |                                |                                |                         | censor rating of R and a budge |
# |                                |                                |                         | t of 23000000 produced by Univ |
# |                                |                                |                         | ersal Pictures with a runtime  |
# |                                |                                |                         | of about 104 and in the genre  |
# |                                |                                |                         | Crime starring Christian Slate |
# |                                |                                |                         | r has had a success score of 6 |
# +--------------------------------+--------------------------------+-------------------------+--------------------------------+

# %% [markdown]
# ## Flatten the query result

# %%
QUERY_FLATTEN_TEXT = ("""
        SELECT
  *
FROM
  ML.GENERATE_TEXT( MODEL movie_insights.llm_model,
    (
    SELECT
      CONCAT('FROM THE FOLLOWING TEXT ABOUT MOVIES, WHAT DO YOU THINK ARE THE FACTORS INFLUENCING A MOVIE SCORE TO BE GREATER THAN 5?: ', movie_data) AS prompt
    FROM (
      SELECT
        REPLACE(STRING_AGG( CONCAT('A movie named ',name, ' from the country ', country, ' with a censor rating of ',rating, ' and a budget of ', budget, ' produced by ', company, ' with a runtime of about ', runtime, ' and in the genre ', genre, ' starring ', star, ' has had a success score of ', score, '') ), ',','. ') AS movie_data
      FROM (
        SELECT
          *
        FROM
          `movie_insights.movie_score`
        WHERE
          CAST(SCORE AS INT64) > 5
        LIMIT
          50) ) AS MOVIES),
    STRUCT( 0.2 AS temperature,
      100 AS max_output_tokens,
      TRUE AS flatten_json_output));
          """)




# Function to wrap text to fit within column width
# def wrap_text(text, width):
#     # Word-wrap text manually by splitting into lines
#     wrapped = "\n".join([text[i:i+width] for i in range(0, len(text), width)])
#     return wrapped

query_flatten_text = client.query(QUERY_FLATTEN_TEXT)
df_flat_text = query_flatten_text.to_dataframe()

column_width = 30  # Around 2 inches (based on a character count of around 10-12 characters per inch)

# Initialize PrettyTable
table = PrettyTable()

# Add column names from the DataFrame
table.field_names = df_flat_text.columns

# Add rows to the PrettyTable with word wrapping applied to each cell
for row in df_flat_text.itertuples(index=False, name=None):
    wrapped_row = [wrap_text(str(cell), column_width) for cell in row]
    table.add_row(wrapped_row)

# Optional: Set alignment for all columns to be left-aligned
table.align = "l"

# Display the table
print(table)
# Out:
# C:\Users\anuj dubey\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\cloud\bigquery\_pandas_helpers.py:207: UserWarning: Unable to determine type for field 'ml_generate_text_rai_result'.
#   warnings.warn("Unable to determine type for field '{}'.".format(bq_field.name))
# +--------------------------------+--------------------------------+-------------------------+--------------------------------+
# | ml_generate_text_llm_result    | ml_generate_text_rai_result    | ml_generate_text_status | prompt                         |
# +--------------------------------+--------------------------------+-------------------------+--------------------------------+
# |  Based on the provided informa | {'blocked': False, 'categories |                         | FROM THE FOLLOWING TEXT ABOUT  |
# | tion, it is difficult to deter | ': array(['Derogatory', 'Finan |                         | MOVIES, WHAT DO YOU THINK ARE  |
# | mine the exact factors influen | ce', 'Insult', 'Profanity', 'S |                         | THE FACTORS INFLUENCING A MOVI |
# | cing a movie score to be great | exual', 'Toxic'],              |                         | E SCORE TO BE GREATER THAN 5?: |
# | er than 5. However, some poten |       dtype=                   |                         |  A movie named American Gigolo |
# | tial factors that could contri | object), 'safetyRatings': arra |                         |  from the country United State |
# | bute to a higher success score | y([{'category': 'Dangerous Con |                         | s with a censor rating of R an |
# |  include:                      | tent', 'probabilityScore': 0.1 |                         | d a budget of 4800000 produced |
# |                                | , 'severity': 'NEGLIGIBLE', 's |                         |  by Paramount Pictures with a  |
# | - **Genre:** Crime             | everityScore': 0.1},           |                         | runtime of about 117 and in th |
# | movies generally tend to have  |        {'                      |                         | e genre Crime starring Richard |
# | lower success scores compared  | category': 'Harassment', 'prob |                         |  Gere has had a success score  |
# | to other genres.               | abilityScore': 0.2, 'severity' |                         | of 6. A movie named Eyewitness |
# |                                | : 'NEGLIGIBLE', 'severityScore |                         |  from the country United State |
# | - **Censor r                   | ': 0.1},                       |                         | s with a censor rating of R an |
# | ating:** Movies with a higher  |        {'category': '          |                         | d a budget of 8500000 produced |
# | censor rating (R) tend to have | Hate Speech', 'probabilityScor |                         |  by Twentieth Century Fox with |
# |  lower success scores compared | e': 0.1, 'severity': 'NEGLIGIB |                         |  a runtime of about 103 and in |
# |  to those with lower ratings ( | LE', 'severityScore': 0.1},    |                         |  the genre Crime starring Will |
# | PG).                           |                                |                         | iam Hurt has had a success sco |
# |                                |      {'category': 'Sexually Ex |                         | re of 6. A movie named True Co |
# | - **Budget:** Movies wit       | plicit', 'probabilityScore': 0 |                         | nfessions from the country Uni |
# | h higher budgets tend          | .1, 'severity': 'NEGLIGIBLE',  |                         | ted States with a censor ratin |
# |                                | 'severityScore': 0.1}],        |                         | g of R and a budget of 1000000 |
# |                                |                                |                         | 0 produced by Chartoff-Winkler |
# |                                | dtype=object), 'scores': array |                         |  Productions with a runtime of |
# |                                | ([0.1, 0.6, 0.2, 0.1, 0.1, 0.1 |                         |  about 108 and in the genre Cr |
# |                                | ])}                            |                         | ime starring Robert De Niro ha |
# |                                |                                |                         | s had a success score of 6. A  |
# |                                |                                |                         | movie named The Amateur from t |
# |                                |                                |                         | he country Canada with a censo |
# |                                |                                |                         | r rating of R and a budget of  |
# |                                |                                |                         | 35524924.14 produced by Balkan |
# |                                |                                |                         |  Productions with a runtime of |
# |                                |                                |                         |  about 112 and in the genre Cr |
# |                                |                                |                         | ime starring John Savage has h |
# |                                |                                |                         | ad a success score of 6. A mov |
# |                                |                                |                         | ie named I.  the Jury from the |
# |                                |                                |                         |  country United States with a  |
# |                                |                                |                         | censor rating of R and a budge |
# |                                |                                |                         | t of 35524924.14 produced by A |
# |                                |                                |                         | merican Cinema Productions wit |
# |                                |                                |                         | h a runtime of about 111 and i |
# |                                |                                |                         | n the genre Crime starring Arm |
# |                                |                                |                         | and Assante has had a success  |
# |                                |                                |                         | score of 6. A movie named Stil |
# |                                |                                |                         | l of the Night from the countr |
# |                                |                                |                         | y United States with a censor  |
# |                                |                                |                         | rating of PG and a budget of 1 |
# |                                |                                |                         | 0000000 produced by United Art |
# |                                |                                |                         | ists with a runtime of about 9 |
# |                                |                                |                         | 3 and in the genre Crime starr |
# |                                |                                |                         | ing Roy Scheider has had a suc |
# |                                |                                |                         | cess score of 6. A movie named |
# |                                |                                |                         |  The Border from the country U |
# |                                |                                |                         | nited States with a censor rat |
# |                                |                                |                         | ing of R and a budget of 22000 |
# |                                |                                |                         | 000 produced by Efer Productio |
# |                                |                                |                         | ns with a runtime of about 108 |
# |                                |                                |                         |  and in the genre Crime starri |
# |                                |                                |                         | ng Jack Nicholson has had a su |
# |                                |                                |                         | ccess score of 6. A movie name |
# |                                |                                |                         | d Love Child from the country  |
# |                                |                                |                         | United States with a censor ra |
# |                                |                                |                         | ting of R and a budget of 3552 |
# |                                |                                |                         | 4924.14 produced by The Ladd C |
# |                                |                                |                         | ompany with a runtime of about |
# |                                |                                |                         |  96 and in the genre Crime sta |
# |                                |                                |                         | rring Amy Madigan has had a su |
# |                                |                                |                         | ccess score of 6. A movie name |
# |                                |                                |                         | d 10 to Midnight from the coun |
# |                                |                                |                         | try United States with a censo |
# |                                |                                |                         | r rating of R and a budget of  |
# |                                |                                |                         | 4520000 produced by Cannon Fil |
# |                                |                                |                         | ms with a runtime of about 101 |
# |                                |                                |                         |  and in the genre Crime starri |
# |                                |                                |                         | ng Charles Bronson has had a s |
# |                                |                                |                         | uccess score of 6. A movie nam |
# |                                |                                |                         | ed The Star Chamber from the c |
# |                                |                                |                         | ountry United States with a ce |
# |                                |                                |                         | nsor rating of R and a budget  |
# |                                |                                |                         | of 35524924.14 produced by Twe |
# |                                |                                |                         | ntieth Century Fox with a runt |
# |                                |                                |                         | ime of about 109 and in the ge |
# |                                |                                |                         | nre Crime starring Michael Dou |
# |                                |                                |                         | glas has had a success score o |
# |                                |                                |                         | f 6. A movie named Tightrope f |
# |                                |                                |                         | rom the country United States  |
# |                                |                                |                         | with a censor rating of R and  |
# |                                |                                |                         | a budget of 35524924.14 produc |
# |                                |                                |                         | ed by The Malpaso Company with |
# |                                |                                |                         |  a runtime of about 114 and in |
# |                                |                                |                         |  the genre Crime starring Clin |
# |                                |                                |                         | t Eastwood has had a success s |
# |                                |                                |                         | core of 6. A movie named Thief |
# |                                |                                |                         |  of Hearts from the country Un |
# |                                |                                |                         | ited States with a censor rati |
# |                                |                                |                         | ng of Not Rated and a budget o |
# |                                |                                |                         | f 9000000 produced by Don Simp |
# |                                |                                |                         | son/Jerry Bruckheimer Films wi |
# |                                |                                |                         | th a runtime of about 100 and  |
# |                                |                                |                         | in the genre Crime starring St |
# |                                |                                |                         | even Bauer has had a success s |
# |                                |                                |                         | core of 6. A movie named The N |
# |                                |                                |                         | ew Kids from the country Unite |
# |                                |                                |                         | d States with a censor rating  |
# |                                |                                |                         | of R and a budget of 35524924. |
# |                                |                                |                         | 14 produced by Columbia Pictur |
# |                                |                                |                         | es with a runtime of about 110 |
# |                                |                                |                         |  and in the genre Crime starri |
# |                                |                                |                         | ng Shannon Presby has had a su |
# |                                |                                |                         | ccess score of 6. A movie name |
# |                                |                                |                         | d That Was Then... This Is Now |
# |                                |                                |                         |  from the country United State |
# |                                |                                |                         | s with a censor rating of R an |
# |                                |                                |                         | d a budget of 35524924.14 prod |
# |                                |                                |                         | uced by Media Ventures with a  |
# |                                |                                |                         | runtime of about 102 and in th |
# |                                |                                |                         | e genre Crime starring Emilio  |
# |                                |                                |                         | Estevez has had a success scor |
# |                                |                                |                         | e of 6. A movie named The Mean |
# |                                |                                |                         |  Season from the country Unite |
# |                                |                                |                         | d States with a censor rating  |
# |                                |                                |                         | of R and a budget of 7000000 p |
# |                                |                                |                         | roduced by David Foster Produc |
# |                                |                                |                         | tions with a runtime of about  |
# |                                |                                |                         | 103 and in the genre Crime sta |
# |                                |                                |                         | rring Kurt Russell has had a s |
# |                                |                                |                         | uccess score of 6. A movie nam |
# |                                |                                |                         | ed The Doctor and the Devils f |
# |                                |                                |                         | rom the country United Kingdom |
# |                                |                                |                         |  with a censor rating of R and |
# |                                |                                |                         |  a budget of 35524924.14 produ |
# |                                |                                |                         | ced by Brooksfilms with a runt |
# |                                |                                |                         | ime of about 93 and in the gen |
# |                                |                                |                         | re Crime starring Timothy Dalt |
# |                                |                                |                         | on has had a success score of  |
# |                                |                                |                         | 6. A movie named No Mercy from |
# |                                |                                |                         |  the country United States wit |
# |                                |                                |                         | h a censor rating of R and a b |
# |                                |                                |                         | udget of 14000000 produced by  |
# |                                |                                |                         | TriStar Pictures with a runtim |
# |                                |                                |                         | e of about 106 and in the genr |
# |                                |                                |                         | e Crime starring Richard Gere  |
# |                                |                                |                         | has had a success score of 6.  |
# |                                |                                |                         | A movie named Quicksilver from |
# |                                |                                |                         |  the country United States wit |
# |                                |                                |                         | h a censor rating of PG and a  |
# |                                |                                |                         | budget of 35524924.14 produced |
# |                                |                                |                         |  by Columbia Pictures with a r |
# |                                |                                |                         | untime of about 105 and in the |
# |                                |                                |                         |  genre Crime starring Kevin Ba |
# |                                |                                |                         | con has had a success score of |
# |                                |                                |                         |  6. A movie named 52 Pick-Up f |
# |                                |                                |                         | rom the country United States  |
# |                                |                                |                         | with a censor rating of R and  |
# |                                |                                |                         | a budget of 35524924.14 produc |
# |                                |                                |                         | ed by Cannon Group with a runt |
# |                                |                                |                         | ime of about 110 and in the ge |
# |                                |                                |                         | nre Crime starring Roy Scheide |
# |                                |                                |                         | r has had a success score of 6 |
# |                                |                                |                         | . A movie named The Morning Af |
# |                                |                                |                         | ter from the country United St |
# |                                |                                |                         | ates with a censor rating of R |
# |                                |                                |                         |  and a budget of 15000000 prod |
# |                                |                                |                         | uced by American Filmworks wit |
# |                                |                                |                         | h a runtime of about 103 and i |
# |                                |                                |                         | n the genre Crime starring Jan |
# |                                |                                |                         | e Fonda has had a success scor |
# |                                |                                |                         | e of 6. A movie named Wisdom f |
# |                                |                                |                         | rom the country United States  |
# |                                |                                |                         | with a censor rating of R and  |
# |                                |                                |                         | a budget of 35524924.14 produc |
# |                                |                                |                         | ed by Gladden Entertainment wi |
# |                                |                                |                         | th a runtime of about 109 and  |
# |                                |                                |                         | in the genre Crime starring Em |
# |                                |                                |                         | ilio Estevez has had a success |
# |                                |                                |                         |  score of 6. A movie named Bla |
# |                                |                                |                         | ck Widow from the country Unit |
# |                                |                                |                         | ed States with a censor rating |
# |                                |                                |                         |  of R and a budget of 10500000 |
# |                                |                                |                         |  produced by Amercent Films wi |
# |                                |                                |                         | th a runtime of about 102 and  |
# |                                |                                |                         | in the genre Crime starring De |
# |                                |                                |                         | bra Winger has had a success s |
# |                                |                                |                         | core of 6. A movie named Less  |
# |                                |                                |                         | Than Zero from the country Uni |
# |                                |                                |                         | ted States with a censor ratin |
# |                                |                                |                         | g of R and a budget of 3552492 |
# |                                |                                |                         | 4.14 produced by Twentieth Cen |
# |                                |                                |                         | tury Fox with a runtime of abo |
# |                                |                                |                         | ut 98 and in the genre Crime s |
# |                                |                                |                         | tarring Andrew McCarthy has ha |
# |                                |                                |                         | d a success score of 6. A movi |
# |                                |                                |                         | e named The Bedroom Window fro |
# |                                |                                |                         | m the country United States wi |
# |                                |                                |                         | th a censor rating of R and a  |
# |                                |                                |                         | budget of 8300000 produced by  |
# |                                |                                |                         | De Laurentiis Entertainment Gr |
# |                                |                                |                         | oup (DEG) with a runtime of ab |
# |                                |                                |                         | out 112 and in the genre Crime |
# |                                |                                |                         |  starring Steve Guttenberg has |
# |                                |                                |                         |  had a success score of 6. A m |
# |                                |                                |                         | ovie named No Man's Land from  |
# |                                |                                |                         | the country United States with |
# |                                |                                |                         |  a censor rating of R and a bu |
# |                                |                                |                         | dget of 8000000 produced by Or |
# |                                |                                |                         | ion Pictures with a runtime of |
# |                                |                                |                         |  about 106 and in the genre Cr |
# |                                |                                |                         | ime starring Charlie Sheen has |
# |                                |                                |                         |  had a success score of 6. A m |
# |                                |                                |                         | ovie named The Believers from  |
# |                                |                                |                         | the country United States with |
# |                                |                                |                         |  a censor rating of R and a bu |
# |                                |                                |                         | dget of 13000000 produced by O |
# |                                |                                |                         | rion Pictures with a runtime o |
# |                                |                                |                         | f about 114 and in the genre C |
# |                                |                                |                         | rime starring Martin Sheen has |
# |                                |                                |                         |  had a success score of 6. A m |
# |                                |                                |                         | ovie named Someone to Watch Ov |
# |                                |                                |                         | er Me from the country United  |
# |                                |                                |                         | States with a censor rating of |
# |                                |                                |                         |  R and a budget of 12800000 pr |
# |                                |                                |                         | oduced by Columbia Pictures wi |
# |                                |                                |                         | th a runtime of about 106 and  |
# |                                |                                |                         | in the genre Crime starring To |
# |                                |                                |                         | m Berenger has had a success s |
# |                                |                                |                         | core of 6. A movie named Priso |
# |                                |                                |                         | n from the country United Stat |
# |                                |                                |                         | es with a censor rating of R a |
# |                                |                                |                         | nd a budget of 4000000 produce |
# |                                |                                |                         | d by Empire Pictures with a ru |
# |                                |                                |                         | ntime of about 102 and in the  |
# |                                |                                |                         | genre Crime starring Lane Smit |
# |                                |                                |                         | h has had a success score of 6 |
# |                                |                                |                         | . A movie named Street Smart f |
# |                                |                                |                         | rom the country United States  |
# |                                |                                |                         | with a censor rating of R and  |
# |                                |                                |                         | a budget of 5000000 produced b |
# |                                |                                |                         | y Golan-Globus Productions wit |
# |                                |                                |                         | h a runtime of about 97 and in |
# |                                |                                |                         |  the genre Crime starring Chri |
# |                                |                                |                         | stopher Reeve has had a succes |
# |                                |                                |                         | s score of 6. A movie named Wh |
# |                                |                                |                         | ite Mischief from the country  |
# |                                |                                |                         | United Kingdom with a censor r |
# |                                |                                |                         | ating of R and a budget of 530 |
# |                                |                                |                         | 0000 produced by Columbia Pict |
# |                                |                                |                         | ures with a runtime of about 1 |
# |                                |                                |                         | 07 and in the genre Crime star |
# |                                |                                |                         | ring Sarah Miles has had a suc |
# |                                |                                |                         | cess score of 6. A movie named |
# |                                |                                |                         |  China Girl from the country U |
# |                                |                                |                         | nited States with a censor rat |
# |                                |                                |                         | ing of R and a budget of 35524 |
# |                                |                                |                         | 924.14 produced by Great Ameri |
# |                                |                                |                         | can Films Limited Partnership  |
# |                                |                                |                         | with a runtime of about 90 and |
# |                                |                                |                         |  in the genre Crime starring J |
# |                                |                                |                         | ames Russo has had a success s |
# |                                |                                |                         | core of 6. A movie named Five  |
# |                                |                                |                         | Corners from the country Unite |
# |                                |                                |                         | d Kingdom with a censor rating |
# |                                |                                |                         |  of R and a budget of 5500000  |
# |                                |                                |                         | produced by Cineplex Odeon Fil |
# |                                |                                |                         | ms with a runtime of about 90  |
# |                                |                                |                         | and in the genre Crime starrin |
# |                                |                                |                         | g Jodie Foster has had a succe |
# |                                |                                |                         | ss score of 6. A movie named T |
# |                                |                                |                         | equila Sunrise from the countr |
# |                                |                                |                         | y United States with a censor  |
# |                                |                                |                         | rating of R and a budget of 23 |
# |                                |                                |                         | 000000 produced by Cinema City |
# |                                |                                |                         |  Films with a runtime of about |
# |                                |                                |                         |  115 and in the genre Crime st |
# |                                |                                |                         | arring Mel Gibson has had a su |
# |                                |                                |                         | ccess score of 6. A movie name |
# |                                |                                |                         | d Betrayed from the country Ja |
# |                                |                                |                         | pan with a censor rating of R  |
# |                                |                                |                         | and a budget of 19000000 produ |
# |                                |                                |                         | ced by United Artists with a r |
# |                                |                                |                         | untime of about 127 and in the |
# |                                |                                |                         |  genre Crime starring Debra Wi |
# |                                |                                |                         | nger has had a success score o |
# |                                |                                |                         | f 6. A movie named Appointment |
# |                                |                                |                         |  with Death from the country U |
# |                                |                                |                         | nited States with a censor rat |
# |                                |                                |                         | ing of PG and a budget of 6000 |
# |                                |                                |                         | 000 produced by Golan-Globus P |
# |                                |                                |                         | roductions with a runtime of a |
# |                                |                                |                         | bout 102 and in the genre Crim |
# |                                |                                |                         | e starring Peter Ustinov has h |
# |                                |                                |                         | ad a success score of 6. A mov |
# |                                |                                |                         | ie named Jack's Back from the  |
# |                                |                                |                         | country United States with a c |
# |                                |                                |                         | ensor rating of R and a budget |
# |                                |                                |                         |  of 1000000 produced by Cinema |
# |                                |                                |                         |  Group with a runtime of about |
# |                                |                                |                         |  97 and in the genre Crime sta |
# |                                |                                |                         | rring James Spader has had a s |
# |                                |                                |                         | uccess score of 6. A movie nam |
# |                                |                                |                         | ed Sunset from the country Uni |
# |                                |                                |                         | ted States with a censor ratin |
# |                                |                                |                         | g of R and a budget of 1600000 |
# |                                |                                |                         | 0 produced by Cecchi Gori Grou |
# |                                |                                |                         | p Tiger Cinematografica with a |
# |                                |                                |                         |  runtime of about 102 and in t |
# |                                |                                |                         | he genre Crime starring Bruce  |
# |                                |                                |                         | Willis has had a success score |
# |                                |                                |                         |  of 6. A movie named Cop from  |
# |                                |                                |                         | the country United States with |
# |                                |                                |                         |  a censor rating of R and a bu |
# |                                |                                |                         | dget of 3000000 produced by At |
# |                                |                                |                         | lantic Entertainment Group wit |
# |                                |                                |                         | h a runtime of about 110 and i |
# |                                |                                |                         | n the genre Crime starring Jam |
# |                                |                                |                         | es Woods has had a success sco |
# |                                |                                |                         | re of 6. A movie named Stormy  |
# |                                |                                |                         | Monday from the country United |
# |                                |                                |                         |  Kingdom with a censor rating  |
# |                                |                                |                         | of R and a budget of 4000000 p |
# |                                |                                |                         | roduced by Atlantic Entertainm |
# |                                |                                |                         | ent Group with a runtime of ab |
# |                                |                                |                         | out 93 and in the genre Crime  |
# |                                |                                |                         | starring Melanie Griffith has  |
# |                                |                                |                         | had a success score of 6. A mo |
# |                                |                                |                         | vie named Kansas from the coun |
# |                                |                                |                         | try United States with a censo |
# |                                |                                |                         | r rating of R and a budget of  |
# |                                |                                |                         | 35524924.14 produced by Trans  |
# |                                |                                |                         | World Entertainment (TWE) with |
# |                                |                                |                         |  a runtime of about 108 and in |
# |                                |                                |                         |  the genre Crime starring Matt |
# |                                |                                |                         |  Dillon has had a success scor |
# |                                |                                |                         | e of 6. A movie named Criminal |
# |                                |                                |                         |  Law from the country United S |
# |                                |                                |                         | tates with a censor rating of  |
# |                                |                                |                         | R and a budget of 35524924.14  |
# |                                |                                |                         | produced by Hemdale with a run |
# |                                |                                |                         | time of about 117 and in the g |
# |                                |                                |                         | enre Crime starring Gary Oldma |
# |                                |                                |                         | n has had a success score of 6 |
# |                                |                                |                         | . A movie named Johnny Handsom |
# |                                |                                |                         | e from the country United Stat |
# |                                |                                |                         | es with a censor rating of R a |
# |                                |                                |                         | nd a budget of 20000000 produc |
# |                                |                                |                         | ed by Carolco Pictures with a  |
# |                                |                                |                         | runtime of about 94 and in the |
# |                                |                                |                         |  genre Crime starring Mickey R |
# |                                |                                |                         | ourke has had a success score  |
# |                                |                                |                         | of 6. A movie named Family Bus |
# |                                |                                |                         | iness from the country United  |
# |                                |                                |                         | States with a censor rating of |
# |                                |                                |                         |  R and a budget of 35524924.14 |
# |                                |                                |                         |  produced by TriStar Pictures  |
# |                                |                                |                         | with a runtime of about 110 an |
# |                                |                                |                         | d in the genre Crime starring  |
# |                                |                                |                         | Sean Connery has had a success |
# |                                |                                |                         |  score of 6. A movie named Rel |
# |                                |                                |                         | entless from the country Unite |
# |                                |                                |                         | d States with a censor rating  |
# |                                |                                |                         | of R and a budget of 4000000 p |
# |                                |                                |                         | roduced by Cinetel Films with  |
# |                                |                                |                         | a runtime of about 92 and in t |
# |                                |                                |                         | he genre Crime starring Judd N |
# |                                |                                |                         | elson has had a success score  |
# |                                |                                |                         | of 6. A movie named The Hot Sp |
# |                                |                                |                         | ot from the country United Sta |
# |                                |                                |                         | tes with a censor rating of R  |
# |                                |                                |                         | and a budget of 13000000 produ |
# |                                |                                |                         | ced by Orion Pictures with a r |
# |                                |                                |                         | untime of about 130 and in the |
# |                                |                                |                         |  genre Crime starring Don John |
# |                                |                                |                         | son has had a success score of |
# |                                |                                |                         |  6. A movie named The Two Jake |
# |                                |                                |                         | s from the country United Stat |
# |                                |                                |                         | es with a censor rating of R a |
# |                                |                                |                         | nd a budget of 19000000 produc |
# |                                |                                |                         | ed by 88 Productions with a ru |
# |                                |                                |                         | ntime of about 137 and in the  |
# |                                |                                |                         | genre Crime starring Jack Nich |
# |                                |                                |                         | olson has had a success score  |
# |                                |                                |                         | of 6. A movie named The First  |
# |                                |                                |                         | Power from the country United  |
# |                                |                                |                         | States with a censor rating of |
# |                                |                                |                         |  R and a budget of 10000000 pr |
# |                                |                                |                         | oduced by Interscope Communica |
# |                                |                                |                         | tions with a runtime of about  |
# |                                |                                |                         | 98 and in the genre Crime star |
# |                                |                                |                         | ring Lou Diamond Phillips has  |
# |                                |                                |                         | had a success score of 6. A mo |
# |                                |                                |                         | vie named Impulse from the cou |
# |                                |                                |                         | ntry United States with a cens |
# |                                |                                |                         | or rating of R and a budget of |
# |                                |                                |                         |  9000000 produced by Warner Br |
# |                                |                                |                         | os. with a runtime of about 10 |
# |                                |                                |                         | 9 and in the genre Crime starr |
# |                                |                                |                         | ing Theresa Russell has had a  |
# |                                |                                |                         | success score of 6. A movie na |
# |                                |                                |                         | med Crossing the Line from the |
# |                                |                                |                         |  country United Kingdom with a |
# |                                |                                |                         |  censor rating of R and a budg |
# |                                |                                |                         | et of 35524924.14 produced by  |
# |                                |                                |                         | Palace Pictures with a runtime |
# |                                |                                |                         |  of about 93 and in the genre  |
# |                                |                                |                         | Crime starring Kenny Ireland h |
# |                                |                                |                         | as had a success score of 6. A |
# |                                |                                |                         |  movie named Mobsters from the |
# |                                |                                |                         |  country United States with a  |
# |                                |                                |                         | censor rating of R and a budge |
# |                                |                                |                         | t of 23000000 produced by Univ |
# |                                |                                |                         | ersal Pictures with a runtime  |
# |                                |                                |                         | of about 104 and in the genre  |
# |                                |                                |                         | Crime starring Christian Slate |
# |                                |                                |                         | r has had a success score of 6 |
# +--------------------------------+--------------------------------+-------------------------+--------------------------------+
